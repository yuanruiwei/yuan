# %%
# -*-coding:utf-8-*-
import urllib.request
from bs4 import BeautifulSoup


def getHtml(url):
    """获取url页面"""
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36'}
    req = urllib.request.Request(url,headers=headers)
    req = urllib.request.urlopen(req)
    content = req.read().decode('utf-8')

    return content


def getComment(url):
    """解析HTML页面"""
    html = getHtml(url)
    soupComment = BeautifulSoup(html, 'html.parser')

    comments = soupComment.findAll('span', 'short')
    onePageComments = []
    for comment in comments:
        # print(comment.getText()+'\n')
        onePageComments.append(comment.getText()+'\n')

    return onePageComments


if __name__ == '__main__':
    f = open('评论.txt', 'w', encoding='utf-8') 
    for page in range(10):  # 豆瓣爬取多页评论需要验证。
        url = 'https://movie.douban.com/subject/25975243/comments?start=' + str(20*page) + '&limit=20&sort=new_score&status=P'
        #https://movie.douban.com/subject/25907063/comments?start=0&limit=20&sort=new_score&status=P

        print('第%s页的评论:' % (page+1))
        print(url + '\n')

        for i in getComment(url):
            f.write(i)
            print(i)
        print('\n')
# Out:
# 第1页的评论:
# https://movie.douban.com/subject/25975243/comments?start=0&limit=20&sort=new_score&status=P
#
# 万万没想到这剧我最喜欢的竟然是司命星君
#
# 杨幂很少女，剧情紧凑。春节被烂片折磨死了，终于可以消磨时间了。
#
# 被赵又廷实力圈粉了～/减一星，配角戏份多的逆天了不能忍，实在讨厌凤九的人设
#
# 我没看过小说，所以小说抄袭不抄袭我不知道，I don't care.但是就说这个电视剧来讲真的很不错，特效方面已经是近几年看的最好的一个了，能看得出来团队真的很用心，演员也很出色。期待！另，说抄袭的请出门左拐书类点评，这里是电视剧，演员和抄袭没关系，请理智对待谢谢。
#
# 大家不应该只用“抄袭”来诟病这部剧，难道它的质量、演员演技值得给两星吗？
#
# 原本打三分吧，喜欢姑父的声音，所以加一分。我觉得豆瓣上那些猛给日剧刷五星、给国产剧刷一星的人，真的有点难理解。还有，共58集的剧，看了三五集就打一分的，拜托，看书的话你连个前言都没看完，有资格打分么？
#
# 难道只有我一个人觉得这部电视剧很好看吗？已经很久很久没有看过这么制作精良的国产片了。墨渊的徒弟个个高颜值，还有几个配角也是。很多人吐槽赵又廷颜值不高，但是现在颜值高的小鲜肉演技撑不起来啊。两个主角负责演技，其他配角负责颜值，没错啊。
#
# 不得不说远超过我的期待。从怎么样都觉得赵又廷颜值不对，到现在他强行演成了我心中夜华的样子，太帅，太惊喜。电视剧总有延伸出旁枝末节扩充情节的部分，大多我觉得都是冗余，但有时候能拍出一种多条线齐头并进的感觉，总体上十分忠于原著。大体是满意的。推荐。
#
# 第三十集男女主角重逢那场戏可以载入中国古装偶像剧史册了
#
# 豆瓣文艺青年品味确实高 俗人的我感觉特效很美，可以说是这几年以来的经典了，作为不看电视不看电影的人来说，我竟然看了好几遍！高伟光和迪丽热巴的剪辑百看不厌
#
# 改成4分，给尊重原著、合理展现暗线、赵又廷
#
# 赵又廷的古装太可怕了，演的是员外么哈哈哈哈哈哈哈哈哈哈
#
# 看完电影过来给个高分加一
#
# 太尬了，赵又廷的颜杨幂的发际线…宛如赵员外和他的早秃小白脸
#
# ...

# %%
#-*-coding:utf-8-*-

import matplotlib.pyplot as plt
from wordcloud import WordCloud
from scipy.misc import imread
import jieba

text = open("评论.txt","rb").read()
#结巴分词
wordlist = jieba.cut(text,cut_all=True)
wl = " ".join(wordlist)
#print(wl)#输出分词之后的txt


#把分词后的txt写入文本文件
#fenciTxt  = open("fenciHou.txt","w+")
#fenciTxt.writelines(wl)
#fenciTxt.close()


#设置词云
wc = WordCloud(background_color = "white", #设置背景颜色
               mask = imread('wang.jpg'),  #设置背景图片
               max_words = 200, #设置最大显示的字数
               stopwords = ["的", "这种", "这样", "还是", "就是", "这个","是","了吧"], #设置停用词
               font_path = "C:\Windows\Fonts\simkai.ttf",  # 设置为楷体 常规
        #设置中文字体，使得词云可以显示（词云默认字体是“DroidSansMono.ttf字体库”，不支持中文）
               max_font_size = 200,  #设置字体最大值
               random_state = 90, #设置有多少种随机生成状态，即有多少种配色方案
    )
myword = wc.generate(wl)#生成词云
wc.to_file('result.jpg')

#展示词云图
plt.imshow(myword)
plt.axis("off")
plt.show()
# Out:
# C:\BUPT-learning\python\anaconda\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
